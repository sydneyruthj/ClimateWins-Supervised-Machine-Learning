# %% [markdown]
# # 1.1 Scaling
#
# ## Contents
# ### 1. Importing data and libraries
# ### 2. Scaling
# #### 2.1 Subset Data
# #### 2.2 Check for missing values
# #### 2.3 Scaling
# ### 3. Export Data

# %% [markdown]
# ## 1. Importing data and libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import os
import sklearn
from sklearn.preprocessing import StandardScaler

# %%
# Define pathname
path = r'/Users/sydneyjohnson/Documents/CF Data Analytics Course/11-2024 ClimateWins Analysis/02 Data'

# %%
df = pd.read_csv(os.path.join(path, 'Dataset-weather-prediction-dataset-processed.csv'))

# %%
df.head()
# Out:
#        DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0  19600101      1                  7               2.1            0.85
# 1  19600102      1                  6               2.1            0.84
# 2  19600103      1                  8               2.1            0.90
# 3  19600104      1                  3               2.1            0.92
# 4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  BASEL_sunshine  ...  VALENTIA_cloud_cover  \
# 0                 0             0.7  ...                     5
# ...

# %%
df.shape
# Out:
# (22950, 170)

# %%
df.reset_index(inplace=True)
df.rename(columns={'index':'id'}, inplace=True)
df.head()
# Out:
#    id      DATE  MONTH  BASEL_cloud_cover  BASEL_wind_speed  BASEL_humidity  \
# 0   0  19600101      1                  7               2.1            0.85
# 1   1  19600102      1                  6               2.1            0.84
# 2   2  19600103      1                  8               2.1            0.90
# 3   3  19600104      1                  3               2.1            0.92
# 4   4  19600105      1                  6               2.1            0.95
#
#    BASEL_pressure  BASEL_global_radiation  BASEL_precipitation  \
# 0           1.018                    0.32                 0.09
# 1           1.018                    0.36                 1.05
# 2           1.018                    0.18                 0.30
# 3           1.018                    0.58                 0.00
# 4           1.018                    0.65                 0.14
#
#    BASEL_snow_depth  ...  VALENTIA_cloud_cover  VALENTIA_humidity  \
# ...

# %%
df.info(verbose=True, show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22950 entries, 0 to 22949
# Data columns (total 171 columns):
#  #    Column                       Non-Null Count  Dtype
# ---   ------                       --------------  -----
#  0    id                           22950 non-null  int64
#  1    DATE                         22950 non-null  int64
#  2    MONTH                        22950 non-null  int64
#  3    BASEL_cloud_cover            22950 non-null  int64
#  4    BASEL_wind_speed             22950 non-null  float64
#  5    BASEL_humidity               22950 non-null  float64
#  6    BASEL_pressure               22950 non-null  float64
#  7    BASEL_global_radiation       22950 non-null  float64
#  8    BASEL_precipitation          22950 non-null  float64
#  9    BASEL_snow_depth             22950 non-null  int64
#  10   BASEL_sunshine               22950 non-null  float64
#  11   BASEL_temp_mean              22950 non-null  float64
# ...

# %%
print(df.columns.tolist())
# Out:
# ['id', 'DATE', 'MONTH', 'BASEL_cloud_cover', 'BASEL_wind_speed', 'BASEL_humidity', 'BASEL_pressure', 'BASEL_global_radiation', 'BASEL_precipitation', 'BASEL_snow_depth', 'BASEL_sunshine', 'BASEL_temp_mean', 'BASEL_temp_min', 'BASEL_temp_max', 'BELGRADE_cloud_cover', 'BELGRADE_humidity', 'BELGRADE_pressure', 'BELGRADE_global_radiation', 'BELGRADE_precipitation', 'BELGRADE_sunshine', 'BELGRADE_temp_mean', 'BELGRADE_temp_min', 'BELGRADE_temp_max', 'BUDAPEST_cloud_cover', 'BUDAPEST_humidity', 'BUDAPEST_pressure', 'BUDAPEST_global_radiation', 'BUDAPEST_precipitation', 'BUDAPEST_sunshine', 'BUDAPEST_temp_mean', 'BUDAPEST_temp_min', 'BUDAPEST_temp_max', 'DEBILT_cloud_cover', 'DEBILT_wind_speed', 'DEBILT_humidity', 'DEBILT_pressure', 'DEBILT_global_radiation', 'DEBILT_precipitation', 'DEBILT_sunshine', 'DEBILT_temp_mean', 'DEBILT_temp_min', 'DEBILT_temp_max', 'DUSSELDORF_cloud_cover', 'DUSSELDORF_wind_speed', 'DUSSELDORF_humidity', 'DUSSELDORF_pressure', 'DUSSELDORF_global_radiation', 'DUSSE
# ...

# %% [markdown]
# ## 2. Scaling

# %% [markdown]
# ### 2.1 Subset temperature data

# %%
#identify the useful numeric columns on temperature
columns = ['BASEL_temp_mean', 'BASEL_temp_min', 'BASEL_temp_max',
           'BELGRADE_temp_mean', 'BELGRADE_temp_min', 'BELGRADE_temp_max',
           'BUDAPEST_temp_mean', 'BUDAPEST_temp_min', 'BUDAPEST_temp_max',
           'DEBILT_temp_mean', 'DEBILT_temp_min', 'DEBILT_temp_max',
           'DUSSELDORF_temp_mean', 'DUSSELDORF_temp_min', 'DUSSELDORF_temp_max',
           'GDANSK_temp_mean', 'GDANSK_temp_min', 'GDANSK_temp_max',
           'HEATHROW_temp_mean', 'HEATHROW_temp_min', 'HEATHROW_temp_max',
           'KASSEL_temp_mean', 'KASSEL_temp_min', 'KASSEL_temp_max',
           'LJUBLJANA_temp_mean', 'LJUBLJANA_temp_min', 'LJUBLJANA_temp_max',
           'MAASTRICHT_temp_mean', 'MAASTRICHT_temp_min', 'MAASTRICHT_temp_max',
           'MADRID_temp_mean', 'MADRID_temp_min', 'MADRID_temp_max',
           'MUNCHENB_temp_mean', 'MUNCHENB_temp_min', 'MUNCHENB_temp_max',
           'OSLO_temp_mean', 'OSLO_temp_min', 'OSLO_temp_max',
           'ROMA_temp_mean',
           'SONNBLICK_temp_mean', 'SONNBLICK_temp_min', 'SONNBLICK_temp_max',
           'STOCKHOLM_temp_mean', 'STOCKHOLM_temp_min', 'STOCKHOLM_temp_max',
           'TOURS_temp_mean', 'TOURS_temp_min', 'TOURS_temp_max',
           'VALENTIA_temp_mean', 'VALENTIA_temp_min', 'VALENTIA_temp_max']

# %% [markdown]
# #### Dataset is missing columns for ROMA_temp_min and ROMA_temp_max

# %%
df_temp = df[columns]
df_temp.head()
# Out:
#    BASEL_temp_mean  BASEL_temp_min  BASEL_temp_max  BELGRADE_temp_mean  \
# 0              6.5             0.8            10.9                 3.7
# 1              6.1             3.3            10.1                 2.9
# 2              8.5             5.1             9.9                 3.1
# 3              6.3             3.8            10.6                 2.0
# 4              3.0            -0.7             6.0                 2.0
#
#    BELGRADE_temp_min  BELGRADE_temp_max  BUDAPEST_temp_mean  \
# 0               -0.9                7.9                 2.4
# 1                2.2                4.4                 2.3
# 2               -0.5                6.4                 2.7
# 3               -2.0                3.0                 2.0
# 4                0.7                2.8                 2.5
#
#    BUDAPEST_temp_min  BUDAPEST_temp_max  DEBILT_temp_mean  DEBILT_temp_min  \
# 0               -0.4                5.1               9.3              7.4
# ...

# %%
### 2.2 Check for missing values
df_temp.isnull().sum()
# Out:
# BASEL_temp_mean         0
# BASEL_temp_min          0
# BASEL_temp_max          0
# BELGRADE_temp_mean      0
# BELGRADE_temp_min       0
# BELGRADE_temp_max       0
# BUDAPEST_temp_mean      0
# BUDAPEST_temp_min       0
# BUDAPEST_temp_max       0
# DEBILT_temp_mean        0
# DEBILT_temp_min         0
# DEBILT_temp_max         0
# DUSSELDORF_temp_mean    0
# DUSSELDORF_temp_min     0
# DUSSELDORF_temp_max     0
# GDANSK_temp_mean        0
# GDANSK_temp_min         0
# GDANSK_temp_max         0
# HEATHROW_temp_mean      0
# HEATHROW_temp_min       0
# HEATHROW_temp_max       0
# KASSEL_temp_mean        0
# KASSEL_temp_min         0
# KASSEL_temp_max         0
# LJUBLJANA_temp_mean     0
# LJUBLJANA_temp_min      0
# LJUBLJANA_temp_max      0
# MAASTRICHT_temp_mean    0
# MAASTRICHT_temp_min     0
# MAASTRICHT_temp_max     0
# MADRID_temp_mean        0
# MADRID_temp_min         0
# MADRID_temp_max         0
# MUNCHENB_temp_mean      0
# MUNCHENB_temp_min       0
# ...

# %% [markdown]
# #### No nulls

# %% [markdown]
# ### 2.3 Scaling

# %%
#create scaler object using StandardScaler from sklearn.preprocessing
scaler = StandardScaler()

# %%
#create new df with scaled data

df_temp_scaled = pd.DataFrame(scaler.fit_transform(df_temp), columns=columns)
df_temp_scaled.head()
# Out:
#    BASEL_temp_mean  BASEL_temp_min  BASEL_temp_max  BELGRADE_temp_mean  \
# 0        -0.528623       -0.845652       -0.478356           -1.016876
# 1        -0.582946       -0.462450       -0.569988           -1.107669
# 2        -0.257010       -0.186545       -0.592896           -1.084971
# 3        -0.555784       -0.385810       -0.512718           -1.209812
# 4        -1.003946       -1.075573       -1.039603           -1.209812
#
#    BELGRADE_temp_min  BELGRADE_temp_max  BUDAPEST_temp_mean  \
# 0          -1.220210          -0.949203           -1.099163
# 1          -0.818702          -1.298119           -1.110927
# 2          -1.168403          -1.098738           -1.063873
# 3          -1.362681          -1.437685           -1.146217
# 4          -1.012980          -1.457623           -1.087400
#
#    BUDAPEST_temp_min  BUDAPEST_temp_max  DEBILT_temp_mean  DEBILT_temp_min  \
# 0          -1.119431          -1.136839         -0.114356         0.263326
# ...

# %% [markdown]
# ## 3. Export Data

# %%
# Export scaled temperature data
df_temp_scaled.to_pickle(os.path.join(path, 'temp_scaled.pkl'))
